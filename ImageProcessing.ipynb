# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
train_images=[]
img=cv2.imread("D://Images//000001.jpg",-1)
print("Image")
# Image read by cv2 is in ndarray
print(type(img))
img2 = img[:,:,::-1]
# plt.imshow(img2)
array=np.asarray(img)
allign=array[:,:,::-1]
out=Image.fromarray(np.uint8(allign))
plt.imshow(allign)
# Out:
# Image
# <class 'numpy.ndarray'>

# %%
import PIL
from PIL import Image
# fig,axes=plt.subplots(3,3)
directory="D://Images//"
img = Image.open(directory+"000001.jpg")
convertarray=np.asarray(img)
# Here allignment is  not required as in PIL when image is converted into array it is already alligned
print(type(convertarray))
print(type(img))
# plt.imshow(convertarray)

# Cobertion from array to Image
out=Image.fromarray(np.uint8(convertarray))
plt.imshow(out)
# Out:
# <class 'numpy.ndarray'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
import skimage
ipho=skimage.io.imread("D://Images/000001.jpg")
# img = skimage.io.imread("imgs/chapter1/tessellate.png")
type(ipho)
narray=np.asarray(ipho)
type(narray)
# Out:
# numpy.ndarray

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(8, 8))
plt.imshow(ipho)
plt.show()
